# %%
import scipy.io.wavfile

import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5

# %%
rate, whistle_data = scipy.io.wavfile.read('whistle.wav')
print(rate)
# Out:
# 44100
# /home/spencer/Workspace/learn-python/signal/venv/lib/python3.4/site-packages/scipy/io/wavfile.py:221: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
whistle_data.shape
# Out:
# (274016, 2)

# %%
plt.plot(whistle_data[:,0])

# %%
plt.plot(whistle_data[:,1])

# %% [markdown]
# # Spectrogram

# %%
import scipy.signal as sig

f, t, Sxx = sig.spectrogram(whistle_data[:,1], rate)

plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0389808d1d78> in <module>()
#       1 import scipy.signal as sig
#       2
# ----> 3 sig.spectrogram(whistle_data[:,1])
#
# NameError: name 'whistle_data' is not defined
