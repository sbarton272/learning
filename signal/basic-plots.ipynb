# %%
import scipy.io.wavfile

import matplotlib.pyplot as plt
#%matplotlib inline
# %matplotlib notebook
#from pylab import rcParams
#rcParams['figure.figsize'] = 10, 5

# %%
rate, whistle_data = scipy.io.wavfile.read('whistle.wav')
print(rate)
# Out:
# 44100

# %%
whistle_data.shape
# Out:
# (274016, 2)

# %%
plt.figure()
plt.plot(whistle_data[:,0])
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.plot(whistle_data[:,1])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # FFT

# %%
import scipy.fftpack as fftpk
import numpy as np

Z = fftpk.fft(whistle_data[:,0])
magZ = np.absolute(Z)
phsZ = np.angle(Z)

plt.figure()
plt.subplot()
# Out:
# array([ 1045035.        ,  1928991.90644099,  3333760.26798452, ...,
#         2240347.72239387,  3333760.26798452,  1928991.90644099])

# %% [markdown]
# # Spectrogram

# %%
import scipy.signal as sig

f, t, Sxx = sig.spectrogram(whistle_data[:,1], rate)

plt.figure()
plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
